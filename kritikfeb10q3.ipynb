# %%
#Q3.PT.1
import numpy as np
import matplotlib.pyplot as plt  # needed to plot

def normal_density(avg, variance, x):
    return (1 / (np.sqrt(2 * np.pi * variance))) * np.exp(-((x - avg) ** 2) / (2 * variance))

x = np.linspace(-10, 10, 1000)

# Plot the normal density functions
plt.figure(figsize=(10, 6))

y_1 = normal_density(0, 1, x)
plt.plot(x, y_1, label=r"avg=0, variance=1")

y_2 = normal_density(0, 2, x)
plt.plot(x, y_2, label=r"avg=0, variance=2")

y_3 = normal_density(0, 0.5, x)
plt.plot(x, y_3, label=r"avg=0, variance=0.5")

y_4 = normal_density(2, 1, x)
plt.plot(x, y_4, label=r"avg=2, variance=1")

# Plot settings
plt.title("Normal Density Function for Different Parameters", fontsize=14)
plt.xlabel("x", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.legend(fontsize=10)
plt.grid(alpha=0.3)

# Show the plot
plt.show()

#Q3.PT.2
import numpy as np
import matplotlib.pyplot as plt  # needed to plot

# Define variables
avg = 0
variation = 1
x = 0
a = 1
b = 3

# Define the normal density function
def normal_density(avg, variance, x):
    return (1 / (np.sqrt(2 * np.pi * variation )) * np.exp(-((x - avg) ** 2) / (2 * variation))

# Define the integration function
def integration(avg, variation, a, b, n=1000):
    w = (b - a) / n  # Step size
  midpoints = np.linspace(a + w / 2, b - w / 2, n)  # Midpoints for integration
    y = normal_density(avg, variation, midpoints)  # Evaluate density function at midpoints
    integral_1 = np.sum(y * w)  # Compute the integral
    return integral_1

# Compute and print the integral
print("The integral from [a, b] is:", integration(avg, variance, a, b))

#Q3.PT.3
import numpy as np
import matplotlib.pyplot as plt  # needed to plot

# Define variables
avg = 171  # Average height
variation= 7.1 ** 2  # Variation in height
a = 162  # Lower limit
b = 190  # Upper limit

# Define the normal density function
def normal_density(avg, variation, x):
    return (1 / (np.sqrt(2 * np.pi * variation))) * np.exp(-((x - avg) ** 2) / (2 * variation))

# Define the integration function
def integration(avg, variation, a, b, n=1000000):
    w= (b - a) / n  # Step size
    midpoints = np.linspace(a + w / 2, b - w / 2, n)  # Midpoints for integration
    y = normal_density(avg, variation, midpoints)  # Evaluate density function at midpoints
    integral = np.sum(y * w)  # Compute the integral
    return integral

# Define the average dosage function
def average_dosage(avg, variation, a, b, n=1000000):
    dosage = lambda x: 2.38 * x ** 2  # D(x) = 2.38 * x^2
    w = (b - a) / n  # Step size
    midpoints = np.linspace(a + w / 2, b - w / 2, n)  # Midpoints for integration
    y = normal_density(avg, variation, midpoints)  # Evaluate density function at midpoints
    dosage_values= dosage(midpoints)  # Compute dosage values
    expected_dosage = np.sum(**dosage_values * y * w)  # Compute expected dosage
    return expected_dosage**

# Compute and print the expected dosage
expected_dosage = average_dosage(avg, variation, a, b)
print("Estimated average dosage:", expected_dosage)
